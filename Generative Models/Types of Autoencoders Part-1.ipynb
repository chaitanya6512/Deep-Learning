# %% [markdown]
# ### Types of Autoencoders:
# - Autoencoders are a type of neural network designed to learn efficient data representations.
# - They work by compressing input data into a smaller, dense format called latent space using an encoder.
# - Then reconstructing the original input from this compressed form using a decoder.
# - This makes autoencoders useful for tasks such as dimensionality reduction, feature selection and noise removal.

# %% [markdown]
# ### 1. Vanilla Autoencoder:
# - Vanilla Autoencoder are the simplest form used for unsupervised learning tasks.
# - They consist of two main parts an encoder that compresses the input data into smaller, dense representation and decoder that reconstructs the oriinal input from this compressed form.
# - Training minimizes reconstruction error which measures the difference between input and output.
# - This optimization is done via backpropagation which helps in updating the network weights to improve reconstruction accuracy.

# %% [markdown]
# ### Implementation of Vanilla Autoencoder:

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

x_train_flat = x_train.reshape(len(x_train), 784)
x_test_flat = x_test.reshape(len(x_test), 784)

n = 10
encoding_dim = 32
input_img = tf.keras.Input(shape=(784,))
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = tf.keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train_flat, x_train_flat, epochs=50, batch_size=256, 
                shuffle=True, validation_data=(x_test_flat, x_test_flat))

decoded_imgs = autoencoder.predict(x_test_flat)

plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test_flat[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.4167 - val_loss: 0.3461
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3309 - val_loss: 0.3226
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3138 - val_loss: 0.3096
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3029 - val_loss: 0.3008
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2959 - val_loss: 0.2955
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2917 - val_loss: 0.2923
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2891 - val_loss: 0.2902
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2874 - val_loss: 0.2891
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2863 - val_loss: 0.2881
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2855 - val_loss: 0.2875
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2850 - val_loss: 0.2870
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2845 - val_loss: 0.2867
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2842 - val_loss: 0.2864
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2839 - val_loss: 0.2860
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2837 - val_loss: 0.2858
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2835 - val_loss: 0.2857
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2833 - val_loss: 0.2856
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2832 - val_loss: 0.2853
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2830 - val_loss: 0.2854
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2829 - val_loss: 0.2851
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2828 - val_loss: 0.2850
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2827 - val_loss: 0.2850
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2827 - val_loss: 0.2849
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2826 - val_loss: 0.2849
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2825 - val_loss: 0.2848
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2824 - val_loss: 0.2847
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2824 - val_loss: 0.2846
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2823 - val_loss: 0.2846
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2823 - val_loss: 0.2845
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2822 - val_loss: 0.2846
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2822 - val_loss: 0.2846
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2821 - val_loss: 0.2844
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2821 - val_loss: 0.2844
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2820 - val_loss: 0.2846
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2820 - val_loss: 0.2843
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2819 - val_loss: 0.2843
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2819 - val_loss: 0.2843
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2819 - val_loss: 0.2843
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2819 - val_loss: 0.2842
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2818 - val_loss: 0.2842
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2818 - val_loss: 0.2841
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2817 - val_loss: 0.2841
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2817 - val_loss: 0.2840
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2817 - val_loss: 0.2840
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2817 - val_loss: 0.2841
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2816 - val_loss: 0.2840
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2816 - val_loss: 0.2840
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2816 - val_loss: 0.2839
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2816 - val_loss: 0.2839
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2816 - val_loss: 0.2840
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### 2. Sparse Autoencoder:
# - Sparse Autoencoder add sparsity constraints that encourage only a small subset of neurons in the hidden layer to activate at once helps in creating a more efficient and focused representation.
# - Unlike vanilla models, they include regularization methods like L1 penalty and dropuout to enforce sparsity.
# - KL Divergence is used to maintain the sparsity level by matching the latent distribution to a predefined sparse target.
# - This selective activation helps in feature selection and learning meaningful patterns while ignoring irrelevant noise.

# %% [markdown]
# ### Implementation of Sparse Autoencoder:

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

x_train_flat = x_train.reshape(len(x_train), 784)
x_test_flat = x_test.reshape(len(x_test), 784)

n = 10
encoding_dim = 32
input_img = tf.keras.Input(shape=(784, ))
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu', 
                                activity_regularizer=tf.keras.regularizers.l1(1e-5))(input_img)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

sparse_autoencoder = tf.keras.Model(input_img, decoded)
sparse_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

sparse_autoencoder.fit(x_train_flat, x_train_flat, epochs=50, batch_size=256, shuffle=True,
                       validation_data=(x_test_flat, x_test_flat))

decoded_imgs = sparse_autoencoder.predict(x_test_flat)

plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test_flat[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4135 - val_loss: 0.3443
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3287 - val_loss: 0.3215
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3132 - val_loss: 0.3095
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3034 - val_loss: 0.3016
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2969 - val_loss: 0.2966
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2930 - val_loss: 0.2936
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2906 - val_loss: 0.2917
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2890 - val_loss: 0.2905
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2879 - val_loss: 0.2897
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2871 - val_loss: 0.2889
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2865 - val_loss: 0.2883
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2860 - val_loss: 0.2879
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2856 - val_loss: 0.2878
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2853 - val_loss: 0.2873
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2850 - val_loss: 0.2871
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2848 - val_loss: 0.2869
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2846 - val_loss: 0.2867
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2844 - val_loss: 0.2865
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2842 - val_loss: 0.2865
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2841 - val_loss: 0.2863
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2839 - val_loss: 0.2862
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2838 - val_loss: 0.2860
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2837 - val_loss: 0.2859
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2836 - val_loss: 0.2859
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2835 - val_loss: 0.2858
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2834 - val_loss: 0.2857
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2833 - val_loss: 0.2857
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2832 - val_loss: 0.2855
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2831 - val_loss: 0.2854
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2831 - val_loss: 0.2854
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2830 - val_loss: 0.2853
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2829 - val_loss: 0.2853
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2829 - val_loss: 0.2853
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2828 - val_loss: 0.2852
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2828 - val_loss: 0.2852
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2827 - val_loss: 0.2851
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2827 - val_loss: 0.2851
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2825 - val_loss: 0.2849
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2825 - val_loss: 0.2849
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2824 - val_loss: 0.2849
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2824 - val_loss: 0.2848
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2824 - val_loss: 0.2848
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2824 - val_loss: 0.2848
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2823 - val_loss: 0.2848
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2823 - val_loss: 0.2847
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2823 - val_loss: 0.2847
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step

# %% [markdown]
# ### 3. Denoising Autoencoder:
# - Denoising Autoencoders are designed to handle corrupted or noisy inputs by learning to reconstruct the clean, original data.
# - Training involves feeding intentionally corrupted inputs and minimizing the reconstruction error against the clean version.
# - This approach forces the model to captures robust features that are invariant to noise.

# %% [markdown]
# ### Implementation of Denoising Autoencoder:

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

x_train_flat = x_train.reshape(len(x_train), 784)
x_test_flat = x_test.reshape(len(x_test), 784)

n = 10
encoding_dim = 32
input_img = tf.keras.Input(shape=(784, ))
encoded = tf.keras.layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = tf.keras.layers.Dense(784, activation='sigmoid')(encoded)

denoising_autoencoder = tf.keras.Model(input_img, decoded)
denoising_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

noise_factor = 0.5
x_train_noisy = x_train_flat + noise_factor * \
    np.random.normal(loc=0.0, scale=1.0, size=x_train_flat.shape)
x_test_noisy = x_test_flat + noise_factor * \
    np.random.normal(loc=0.0, scale=1.0, size=x_test_flat.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

denoising_autoencoder.fit(x_train_noisy, x_train_flat,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(x_test_noisy, x_test_flat))

decoded_imgs = denoising_autoencoder.predict(x_test_noisy)

plt.figure(figsize=(20, 6))
for i in range(n):
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test_flat[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    ax = plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4273 - val_loss: 0.3584
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3426 - val_loss: 0.3362
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3292 - val_loss: 0.3280
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3230 - val_loss: 0.3234
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3187 - val_loss: 0.3198
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3154 - val_loss: 0.3169
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3129 - val_loss: 0.3145
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3108 - val_loss: 0.3127
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3092 - val_loss: 0.3112
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3079 - val_loss: 0.3100
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3067 - val_loss: 0.3091
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3057 - val_loss: 0.3081
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3049 - val_loss: 0.3075
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3043 - val_loss: 0.3070
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3039 - val_loss: 0.3066
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3035 - val_loss: 0.3062
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3032 - val_loss: 0.3060
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3030 - val_loss: 0.3059
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3029 - val_loss: 0.3056
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3026 - val_loss: 0.3055
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3025 - val_loss: 0.3053
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3023 - val_loss: 0.3052
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3022 - val_loss: 0.3052
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3022 - val_loss: 0.3055
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3020 - val_loss: 0.3049
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3019 - val_loss: 0.3049
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3018 - val_loss: 0.3051
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3018 - val_loss: 0.3047
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3016 - val_loss: 0.3049
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3016 - val_loss: 0.3046
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3015 - val_loss: 0.3045
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3015 - val_loss: 0.3045
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3014 - val_loss: 0.3045
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3014 - val_loss: 0.3044
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3043
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3043
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3012 - val_loss: 0.3044
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3011 - val_loss: 0.3043
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3012 - val_loss: 0.3043
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3011 - val_loss: 0.3042
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3011 - val_loss: 0.3045
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3010 - val_loss: 0.3041
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3010 - val_loss: 0.3041
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3010 - val_loss: 0.3042
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3009 - val_loss: 0.3040
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3010 - val_loss: 0.3042
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3009 - val_loss: 0.3040
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3008 - val_loss: 0.3040
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3009 - val_loss: 0.3041
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3008 - val_loss: 0.3040
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
