# %% [markdown]
# ### What is Padding?
# - Padding is a technique used to preserve the spatial dimensions of the input image after convolution operations on a feature map.
# - Padding involves adding extra pixels around the border of the input feature map before convolution.
# ### This can be done in Two ways:
# #### 1. Valid Padding:
# - In the valid padding, no padding is added to the input feature map.
# - The output feature map is smaller than the input of the feature map.
# - This is useful when we want to reduce the spatial dimensions of the feature maps.
# - So, (nxn)*(fxf) ⟶ (n-f+1)x(n-f+1).
#   - where,
#     - nxn - is the dimension of input image.
#     - fxf - is kernel size.
#     - n-f+1 - is output image size.
#     - * - represents a convolution operation.
# #### 2. Same Padding:
# - In the same padding, padding is added to the input feature map such that the size of the output feature map is the same as the size of the input feature map.
# - This is useful when we want to preserve the spatial dimensions of the feature maps.
# - So, [(n+2p) x (n+2p) image]*[(fxf) filter] ⟶ [(nxn) image].
#   - where,
#     - p = (f-1)/2 (because n+2p -f +1=n).

# %% [markdown]
# - The number of pixels to be added for padding can be calculated based on the size of the kernel and the desired output of the feature map size.
# - The most common padding value is zero-padding, which involves adding zeros to the borders of the input feature map.
# - Padding can help in reducing the loss of information at the borders of the input feature map and can improve the performance of the model.
# - Overall, padding is an important technique in CNNs that help preserving the spatial dimensions of the feature maps and can improve the performance of the model.
